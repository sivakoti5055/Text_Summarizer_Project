# %%
import os

# %%
# %pwd
# Out:
# 'd:\\Text_Summarize_Project\\Text_Summarizer_Project\\research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'd:\\Text_Summarize_Project\\Text_Summarizer_Project'

# %%
from dataclasses import dataclass
from pathlib import Path
from text_summarize.constants import *
from text_summarize.utils.common import read_yaml,create_directories

# %%
@dataclass(frozen=True)
class ModelEvaluationConfig:
    root_dir: Path
    data_path: Path
    model_path: Path
    tokenizer_path: Path
    metric_file_name: Path

# %%
from text_summarize.constants import *
from text_summarize.utils.common import read_yaml, create_directories

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath = CONFIG_FILE_PATH,
        params_filepath = PARAM_FILE_PATH):

        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)

        create_directories([self.config.artifacts_root])


    
    def get_model_evaluation_config(self) -> ModelEvaluationConfig:
        config = self.config.model_evaluation

        create_directories([config.root_dir])

        model_evaluation_config = ModelEvaluationConfig(
            root_dir=config.root_dir,
            data_path=config.data_path,
            model_path = config.model_path,
            tokenizer_path = config.tokenizer_path,
            metric_file_name = config.metric_file_name
           
        )

        return model_evaluation_config

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets>=2.0.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (4.7.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (2.2.6)
# Requirement already satisfied: dill in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (0.4.0)
# Requirement already satisfied: pandas in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (2.3.3)
# Requirement already satisfied: requests>=2.19.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (2.32.5)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (4.67.3)
# Requirement already satisfied: xxhash in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (3.6.0)
# Requirement already satisfied: multiprocess in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (0.70.18)
# Requirement already satisfied: fsspec>=2021.05.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (2026.2.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (1.6.0)
# Requirement already satisfied: packaging in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from evaluate) (25.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from datasets>=2.0.0->evaluate) (3.25.1)
# Requirement already satisfied: pyarrow>=21.0.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from datasets>=2.0.0->evaluate) (23.0.1)
# Requirement already satisfied: httpx<1.0.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from datasets>=2.0.0->evaluate) (0.28.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from datasets>=2.0.0->evaluate) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from fsspec[http]>=2021.05.0->evaluate) (3.13.3)
# Requirement already satisfied: anyio in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (4.12.1)
# Requirement already satisfied: certifi in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (1.0.9)
# Requirement already satisfied: idna in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from httpx<1.0.0->datasets>=2.0.0->evaluate) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=2.0.0->evaluate) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.3.2 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (1.3.2)
# Requirement already satisfied: typer in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from huggingface-hub>=0.7.0->evaluate) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from requests>=2.19.0->evaluate) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from requests>=2.19.0->evaluate) (2.6.3)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from tqdm>=4.62.1->evaluate) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from anyio->httpx<1.0.0->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from pandas->evaluate) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from pandas->evaluate) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from typer->huggingface-hub>=0.7.0->evaluate) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lenovo\anaconda3\envs\textsum\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub>=0.7.0->evaluate) (0.1.2)
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.6

# %%
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
from datasets import load_dataset, load_from_disk
from evaluate import load
import torch
import pandas as pd
from tqdm import tqdm

# %%
class ModelEvaluation:
    def __init__(self, config: ModelEvaluationConfig):
        self.config = config


    
    def generate_batch_sized_chunks(self,list_of_elements, batch_size):
        """split the dataset into smaller batches that we can process simultaneously
        Yield successive batch-sized chunks from list_of_elements."""
        for i in range(0, len(list_of_elements), batch_size):
            yield list_of_elements[i : i + batch_size]

    
    def calculate_metric_on_test_ds(self,dataset, metric, model, tokenizer, 
                               batch_size=16, device="cuda" if torch.cuda.is_available() else "cpu", 
                               column_text="article", 
                               column_summary="highlights"):
        article_batches = list(self.generate_batch_sized_chunks(dataset[column_text], batch_size))
        target_batches = list(self.generate_batch_sized_chunks(dataset[column_summary], batch_size))

        for article_batch, target_batch in tqdm(
            zip(article_batches, target_batches), total=len(article_batches)):
            
            inputs = tokenizer(article_batch, max_length=1024,  truncation=True, 
                            padding="max_length", return_tensors="pt")
            
            summaries = model.generate(input_ids=inputs["input_ids"].to(device),
                            attention_mask=inputs["attention_mask"].to(device), 
                            length_penalty=0.8, num_beams=8, max_length=128)
            ''' parameter for length penalty ensures that the model does not generate sequences that are too long. '''
            
            # Finally, we decode the generated texts, 
            # replace the  token, and add the decoded texts with the references to the metric.
            decoded_summaries = [tokenizer.decode(s, skip_special_tokens=True, 
                                    clean_up_tokenization_spaces=True) 
                for s in summaries]      
            
            decoded_summaries = [d.replace("", " ") for d in decoded_summaries]
            
            
            metric.add_batch(predictions=decoded_summaries, references=target_batch)
            
        #  Finally compute and return the ROUGE scores.
        score = metric.compute()
        return score


    def evaluate(self):
        device = "cuda" if torch.cuda.is_available() else "cpu"
        tokenizer = AutoTokenizer.from_pretrained(self.config.tokenizer_path)
        model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(self.config.model_path).to(device)
       
        #loading data 
        dataset_samsum_pt = load_from_disk(self.config.data_path)


        rouge_names = ["rouge1", "rouge2", "rougeL", "rougeLsum"]
  
        rouge_metric = load('rouge')

        score = self.calculate_metric_on_test_ds(
        dataset_samsum_pt['test'][0:10], rouge_metric, model_pegasus, tokenizer, batch_size = 2, column_text = 'dialogue', column_summary= 'summary'
            )

        rouge_dict = dict((rn, score[rn].mid.fmeasure ) for rn in rouge_names )

        df = pd.DataFrame(rouge_dict, index = ['pegasus'] )
        df.to_csv(self.config.metric_file_name, index=False)

# %%
try:
    config = ConfigurationManager()
    model_evaluation_config = config.get_model_evaluation_config()
    model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
    model_evaluation_config.evaluate()
except Exception as e:
    raise e
# Out:
# [2026-04-12 12:43:40,821:INFO:common:yaml file config\config.yaml loaded successfuly]
# [2026-04-12 12:43:40,832:INFO:common:yaml file params.yaml loaded successfuly]
# [2026-04-12 12:43:40,832:INFO:common:created directory at artifacts]
# [2026-04-12 12:43:40,843:INFO:common:created directory at artifacts/model_evaluation]
# ---------------------------------------------------------------------------
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\utils\hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\huggingface_hub\utils\_validators.py:85, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\huggingface_hub\utils\_validators.py:133, in validate_repo_id(repo_id)
#     132 if repo_id.count("/") > 1:
# --> 133     raise HFValidationError(
#     134         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     135         f" '{repo_id}'. Use `repo_type` argument if needed."
#     136     )
#     138 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\models\auto\tokenization_auto.py:685, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     684 try:
# --> 685     config = AutoConfig.from_pretrained(
#     686         pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     687     )
#     688 except (ValueError, OSError):
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\models\auto\configuration_auto.py:1483, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1481 code_revision = kwargs.pop("code_revision", None)
# -> 1483 config_dict, unused_kwargs = PreTrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#    1484 has_remote_code = "auto_map" in config_dict and "AutoConfig" in config_dict["auto_map"]
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\configuration_utils.py:670, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     669 # Get config dict associated with the base config file
# --> 670 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     671 if config_dict is None:
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\configuration_utils.py:725, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     723 try:
#     724     # Load from local folder or from cache or download from model Hub and cache
# --> 725     resolved_config_file = cached_file(
#     726         pretrained_model_name_or_path,
#     727         configuration_file,
#     728         cache_dir=cache_dir,
#     729         force_download=force_download,
#     730         proxies=proxies,
#     731         local_files_only=local_files_only,
#     732         token=token,
#     733         user_agent=user_agent,
#     734         revision=revision,
#     735         subfolder=subfolder,
#     736         _commit_hash=commit_hash,
#     737     )
#     738     if resolved_config_file is None:
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\utils\hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     228 """
#     229 Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)
#     276 ```
#     277 """
# --> 278 file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279 file = file[0] if file is not None else file
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\utils\hub.py:473, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     472 elif isinstance(e, ValueError):
# --> 473     raise OSError(f"{e}") from e
#     475 # Now we try to recover if we can find all files correctly in the cache
#
# OSError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
#
# During handling of the above exception, another exception occurred:
#
# HFValidationError                         Traceback (most recent call last)
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\utils\hub.py:422, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     420 if len(full_filenames) == 1:
#     421     # This is slightly better for only 1 file
# --> 422     hf_hub_download(
#     423         path_or_repo_id,
#     424         filenames[0],
#     425         subfolder=None if len(subfolder) == 0 else subfolder,
#     426         repo_type=repo_type,
#     427         revision=revision,
#     428         cache_dir=cache_dir,
#     429         user_agent=user_agent,
#     430         force_download=force_download,
#     431         proxies=proxies,
#     432         token=token,
#     433         local_files_only=local_files_only,
#     434         tqdm_class=tqdm_class,
#     435     )
#     436 else:
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\huggingface_hub\utils\_validators.py:85, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#      84     if arg_name in ["repo_id", "from_id", "to_id"]:
# ---> 85         validate_repo_id(arg_value)
#      87 kwargs = smoothly_deprecate_legacy_arguments(fn_name=fn.__name__, kwargs=kwargs)
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\huggingface_hub\utils\_validators.py:133, in validate_repo_id(repo_id)
#     132 if repo_id.count("/") > 1:
# --> 133     raise HFValidationError(
#     134         "Repo id must be in the form 'repo_name' or 'namespace/repo_name':"
#     135         f" '{repo_id}'. Use `repo_type` argument if needed."
#     136     )
#     138 if not REPO_ID_REGEX.match(repo_id):
#
# HFValidationError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# Cell In[21], line 7
#       5     model_evaluation_config.evaluate()
#       6 except Exception as e:
# ----> 7     raise e
#
# Cell In[21], line 5
#       3     model_evaluation_config = config.get_model_evaluation_config()
#       4     model_evaluation_config = ModelEvaluation(config=model_evaluation_config)
# ----> 5     model_evaluation_config.evaluate()
#       6 except Exception as e:
#       7     raise e
#
# Cell In[20], line 50, in ModelEvaluation.evaluate(self)
#      48 def evaluate(self):
#      49     device = "cuda" if torch.cuda.is_available() else "cpu"
# ---> 50     tokenizer = AutoTokenizer.from_pretrained(self.config.tokenizer_path)
#      51     model_pegasus = AutoModelForSeq2SeqLM.from_pretrained(self.config.model_path).to(device)
#      53     #loading data
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\models\auto\tokenization_auto.py:689, in AutoTokenizer.from_pretrained(cls, pretrained_model_name_or_path, *inputs, **kwargs)
#     685         config = AutoConfig.from_pretrained(
#     686             pretrained_model_name_or_path, trust_remote_code=trust_remote_code, **kwargs
#     687         )
#     688     except (ValueError, OSError):
# --> 689         config = PreTrainedConfig.from_pretrained(pretrained_model_name_or_path, **kwargs)
#     691 config_model_type = config.model_type
#     693 # Next, let's try to use the tokenizer_config file to get the tokenizer class.
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\configuration_utils.py:629, in PreTrainedConfig.from_pretrained(cls, pretrained_model_name_or_path, cache_dir, force_download, local_files_only, token, revision, **kwargs)
#     626 kwargs["local_files_only"] = local_files_only
#     627 kwargs["revision"] = revision
# --> 629 config_dict, kwargs = cls.get_config_dict(pretrained_model_name_or_path, **kwargs)
#     630 if cls.base_config_key and cls.base_config_key in config_dict:
#     631     config_dict = config_dict[cls.base_config_key]
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\configuration_utils.py:670, in PreTrainedConfig.get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     668 original_kwargs = copy.deepcopy(kwargs)
#     669 # Get config dict associated with the base config file
# --> 670 config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#     671 if config_dict is None:
#     672     return {}, kwargs
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\configuration_utils.py:725, in PreTrainedConfig._get_config_dict(cls, pretrained_model_name_or_path, **kwargs)
#     721 configuration_file = kwargs.pop("_configuration_file", CONFIG_NAME) if gguf_file is None else gguf_file
#     723 try:
#     724     # Load from local folder or from cache or download from model Hub and cache
# --> 725     resolved_config_file = cached_file(
#     726         pretrained_model_name_or_path,
#     727         configuration_file,
#     728         cache_dir=cache_dir,
#     729         force_download=force_download,
#     730         proxies=proxies,
#     731         local_files_only=local_files_only,
#     732         token=token,
#     733         user_agent=user_agent,
#     734         revision=revision,
#     735         subfolder=subfolder,
#     736         _commit_hash=commit_hash,
#     737     )
#     738     if resolved_config_file is None:
#     739         return None, kwargs
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\utils\hub.py:278, in cached_file(path_or_repo_id, filename, **kwargs)
#     223 def cached_file(
#     224     path_or_repo_id: str | os.PathLike,
#     225     filename: str,
#     226     **kwargs,
#     227 ) -> str | None:
#     228     """
#     229     Tries to locate a file in a local folder and repo, downloads and cache it if necessary.
#     230
#    (...)
#     276     ```
#     277     """
# --> 278     file = cached_files(path_or_repo_id=path_or_repo_id, filenames=[filename], **kwargs)
#     279     file = file[0] if file is not None else file
#     280     return file
#
# File c:\Users\LENOVO\anaconda3\envs\textSum\lib\site-packages\transformers\utils\hub.py:473, in cached_files(path_or_repo_id, filenames, cache_dir, force_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, tqdm_class, **deprecated_kwargs)
#     467     raise OSError(
#     468         f"PermissionError at {e.filename} when downloading {path_or_repo_id}. "
#     469         "Check cache directory permissions. Common causes: 1) another user is downloading the same model (please wait); "
#     470         "2) a previous download was canceled and the lock file needs manual removal."
#     471     ) from e
#     472 elif isinstance(e, ValueError):
# --> 473     raise OSError(f"{e}") from e
#     475 # Now we try to recover if we can find all files correctly in the cache
#     476 resolved_files = [
#     477     _get_cache_file_to_return(path_or_repo_id, filename, cache_dir, revision, repo_type)
#     478     for filename in full_filenames
#     479 ]
#
# OSError: Repo id must be in the form 'repo_name' or 'namespace/repo_name': 'artifacts/model_trainer/tokenizer'. Use `repo_type` argument if needed.
